# %%
import pandas as pd
import plotly.express as px
from data_utils import read_rpt_file, replace_null_with_none, get_available_free_service_km, get_available_free_warranty_year, get_correct_dtype
from exploratory_utils import get_missing_percentage, compute_r_squared
from visualization import Plotting

# Configuration
from config import ModelVariables

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 200

# %%
responding_var = ModelVariables().responding_variable
exploration_vars = ModelVariables().numeric_variables + ModelVariables().categorical_variables + ModelVariables().date_variables

# %%
df = read_rpt_file('./data/DatiumTrain.rpt')

# %%
df.describe()

# Some columns are duplicated / equivalent to another (eg. Make vs MakeCode or Model vs FamilyCode)
# There are some columns having string 'NULL' instead of None. it need to be replaced.
# Out:
#          ﻿Make      Model MakeCode FamilyCode YearGroup MonthGroup  \
# count    50704      50704    50704      50704     50704      50704
# unique      52        582       52        581        42         13
# top     Toyota  Commodore     TOYO    COMMODO      2010          0
# freq     15720       6827    15720       6827      4200      37580
#
#        SequenceNum                            Description CurrentRelease  \
# count        50704                                  50704          50704
# unique         102                                   8568              1
# top              1  ACV40R Altise Sedan 4dr Auto 5sp 2.4i              F
# freq          8218                                    707          50704
#
#        ImportFlag LimitedEdition Series SeriesModelYear BadgeDescription  \
# count       50704          50704  50704           50704            50704
# unique          1              2   1036              47              649
# top             L              F     VE            NULL             NULL
# freq        50704          49893   1713           35164             6605
#
#        BadgeSecondaryDescription BodyStyleDescription BodyConfigDescription  \
# count                      50704                50704                 50704
# unique                       187                   16                     4
# top                         NULL                Sedan                  NULL
# freq                       48271                20594                 42021
#
#        WheelBaseConfig Roofline ExtraIdentification  DriveDescription  \
# count            50704    50704               50704             50704
# unique               5        4                 134                 7
# top               NULL     NULL                NULL  Rear Wheel Drive
# freq             48905    50184               47447             21863
#
#        DriveCode GearTypeDescription GearLocationDescription GearNum DoorNum  \
# count      50704               50704                   50704   50704   50704
# unique         7                   8                       7      10       4
# top          RWD           Automatic                   Floor       4       4
# freq       21863               22783                   47630   24515   26930
#
#        EngineSize EngineDescription Cylinders    FuelTypeDescription  \
# count       50704             50704     50704                  50704
# unique        420                63         8                      6
# top          3984               4.0         4  Petrol - Unleaded ULP
# freq         7430              8169     25153                  38405
#
#        InductionDescription OptionCategory CamDescription  \
# count                 50704          50704          50704
# unique                    7              6             11
# top               Aspirated           PASS  DOHC with VVT
# freq                  42186          31771          22571
#
#        EngineTypeDescription FuelCapacity FuelDeliveryDescription  \
# count                  50704        50704                   50704
# unique                     3           86                       7
# top                   Piston           70   Multi-Point Injection
# freq                   49847         7926                   41197
#
#        MethodOfDeliveryDescription GrossCombinationMAss GrossVehicleMass  \
# count                        50704                50704            50704
# unique                           4                  661              583
# top          Electronic Sequential                 NULL             NULL
# freq                         38453                26180            20241
#
#                       VIN WheelBase Height Length  Width KerbWeight TareMass  \
# count               50704     50704  50703  50703  50703      50703    50703
# unique               3979       339    452    739    287       1302     1160
# top     6FPAAAJGSW3M#####      2775   1470   4815   1842       NULL     NULL
# freq                 1474      3485   2569   2368   3292       1533    10550
#
#        PayLoad   Power PowerRPMFrom PowerRPMTo Torque TorqueRPMFrom  \
# count    50703   50703        50703      50703  50703         50703
# unique     853     232           15         65    331            45
# top       NULL  147.00         NULL       6000    380          NULL
# freq     25088    2551        50494       9919   2670         46004
#
#        TorqueRPMTo RonRating SeatCapacity ModelCode  \
# count        50703     50703        50703     50703
# unique          84         4           13      3387
# top           4000        91            5      NULL
# freq          6276     37643        39645     10429
#
#        BuildCountryOriginDescription ValvesCylinder EngineCycleDescription  \
# count                          50703          50703                  50703
# unique                            31              5                      2
# top                        AUSTRALIA              4               4 Stroke
# freq                           23478          37584                  50685
#
#        EngineConfigurationDescription EngineLocation  EngineNum Acceleration  \
# count                           50703          50703      50703        50703
# unique                             11              4       1522          133
# top                           In-line          Front  VA-######         NULL
# freq                            31621          50650       2078        35573
#
#        FrontTyreSize RearTyreSize FrontRimDesc RearRimDesc TowingBrakes  \
# count          50703        50703        50703       50703        50703
# unique           296          314           70          83          161
# top       205/65 R15   205/65 R15       15x6.0      15x6.0         2100
# freq            7964         7958        11270       11076         7050
#
#        TowingNoBrakes WarrantyCustAssist FreeScheduledService WarrantyYears  \
# count           50703              50703                50703         50703
# unique             72                 60                    8             7
# top               750               NULL                 NULL             3
# freq            19485              27948                50607         44295
#
#        WarrantyKM FirstServiceKM FirstServiceMonths RegServiceMonths  \
# count       50703          50703              50703            50703
# unique         14             18                  9                7
# top        100000           NULL               NULL             NULL
# freq        41295          19971              22812            19957
#
#        AltEngEngineType AltEngBatteryType AltEngCurrentType AltEngAmpHours  \
# count             50703             50703             50703          50703
# unique                3                 3                 3              3
# top                NULL              NULL              NULL           NULL
# freq              49865             49865             49865          50697
#
#        AltEngVolts AltEngChargingMethod AltEngPower AltEngPowerFrom  \
# count        50703                50703       50703           50703
# unique           9                    4          12               3
# top           NULL                 NULL        NULL            NULL
# freq         49867                49865       49867           50547
#
#        AltEngPowerTo AltEngTorque AltEngTorqueFrom AltEngTorqueTo AltEngDrive  \
# count          50703        50703            50703          50703       50703
# unique             6           13                1              5           4
# top             NULL         NULL             NULL           NULL        NULL
# freq           50466        49918            50703          50539       49868
#
#        NormalChargeMins QuickChargeMins NormalChargeVoltage  \
# count             50703           50703               50703
# unique                1               1                   1
# top                NULL            NULL                NULL
# freq              50703           50703               50703
#
#        QuickChargeVoltage KMRangeElectricEng ElectricEngineLocation  \
# count               50703              50703                  50703
# unique                  1                  2                      3
# top                  NULL               NULL                   NULL
# freq                50703              50701                  50677
#
#        TopSpeedElectricEng GreenhouseRating AirpollutionRating  \
# count                50703            50703              50703
# unique                   2               17                 14
# top                   NULL             NULL               NULL
# freq                 50701            26059              26073
#
#        OverallGreenStarRating CO2Combined CO2Urban CO2ExtraUrban FuelUrban  \
# count                   50703       50703    50703         50703     50703
# unique                     11         272      293           166       183
# top                      NULL        NULL     NULL          NULL      NULL
# freq                    25882       16973    38591         38593     21309
#
#        FuelExtraurban FuelCombined EmissionStandard MaxEthanolBlend  \
# count           50703        50703            50703           50703
# unique             95          134                6               4
# top              NULL         NULL             NULL            NULL
# freq            22462         4357            41754           48553
#
#        AncapRating VFactsClass VFactsSegment VFactsPrice IsPPlateApproved  \
# count        50703       50703         50703       50703            50703
# unique           6           5            14          18                2
# top           NULL   Passenger         Large      < $70K                T
# freq         24738       31672         20267       19376            48580
#
#        AverageKM GoodKM AvgWholesale AvgRetail GoodWholesale GoodRetail  \
# count      50703  50703        50703     50703         50703      50703
# unique        90     78          752       840           800        910
# top          180    140         NULL      NULL          NULL       3000
# freq        3940   4029        13109      4730          6752        989
#
#        TradeMin TradeMax PrivateMax NewPrice Colour         Branch  \
# count     50703    50703      50703    50703  50703          50703
# unique      422      440        520     4237    906             18
# top        NULL     NULL       4100    29990  White  Belmore (NSW)
# freq      13109    13109       1482     1106  15738          15188
#
#        SaleCategory                Sold_Date Compliance_Date Age_Comp_Months  \
# count         50703                    50703           50703           50703
# unique            6                     4747             405             278
# top         Auction  2015-07-01 00:00:00.000         06/2010              38
# freq          38804                       62             431            1994
#
#            KM Sold_Amount
# count   50703       50703
# unique  43679        2716
# top         0        0.00
# freq       48         734

# %%
df.dtypes.head(20)

# We need to provide the dtypes explicitly to the variables
# Out:
# Make                        object
# Model                        object
# MakeCode                     object
# FamilyCode                   object
# YearGroup                    object
# MonthGroup                   object
# SequenceNum                  object
# Description                  object
# CurrentRelease               object
# ImportFlag                   object
# LimitedEdition               object
# Series                       object
# SeriesModelYear              object
# BadgeDescription             object
# BadgeSecondaryDescription    object
# BodyStyleDescription         object
# BodyConfigDescription        object
# WheelBaseConfig              object
# Roofline                     object
# ExtraIdentification          object
# dtype: object

# %%
# Missing data overview for each columns
df = replace_null_with_none(df)
missing_data_count = get_missing_percentage(df)
print(missing_data_count)

# Those columns with high missing data percentage are impossible to be impute with valid values and does not bring much insights. Thus, we will exclude them
# Out:
#                                 Count  Missing Data Percentage
# ﻿Make                               0                 0.000000
# Model                               0                 0.000000
# MakeCode                            0                 0.000000
# FamilyCode                          0                 0.000000
# YearGroup                           0                 0.000000
# MonthGroup                          0                 0.000000
# SequenceNum                         0                 0.000000
# Description                         0                 0.000000
# CurrentRelease                      0                 0.000000
# ImportFlag                          0                 0.000000
# LimitedEdition                      0                 0.000000
# Series                            850                 1.676396
# SeriesModelYear                 35164                69.351530
# BadgeDescription                 6605                13.026586
# BadgeSecondaryDescription       48271                95.201562
# BodyStyleDescription                0                 0.000000
# BodyConfigDescription           42021                82.875118
# WheelBaseConfig                 48905                96.451956
# Roofline                        50184                98.974440
# ExtraIdentification             47447                93.576444
# DriveDescription                    0                 0.000000
# DriveCode                           0                 0.000000
# GearTypeDescription                 0                 0.000000
# GearLocationDescription             0                 0.000000
# GearNum                             1                 0.001972
# DoorNum                             0                 0.000000
# EngineSize                          0                 0.000000
# EngineDescription                   0                 0.000000
# Cylinders                           0                 0.000000
# FuelTypeDescription                 0                 0.000000
# InductionDescription                0                 0.000000
# OptionCategory                      0                 0.000000
# CamDescription                    218                 0.429946
# EngineTypeDescription               0                 0.000000
# FuelCapacity                      812                 1.601452
# FuelDeliveryDescription             0                 0.000000
# MethodOfDeliveryDescription        22                 0.043389
# GrossCombinationMAss            26180                51.633007
# GrossVehicleMass                20241                39.919927
# VIN                               578                 1.139950
# WheelBase                         143                 0.282029
# Height                            719                 1.418034
# Length                            659                 1.299700
# Width                             657                 1.295756
# KerbWeight                       1534                 3.025402
# TareMass                        10551                20.809009
# PayLoad                         25089                49.481303
# Power                             112                 0.220890
# PowerRPMFrom                    50495                99.587804
# PowerRPMTo                        138                 0.272168
# Torque                            273                 0.538419
# TorqueRPMFrom                   46005                90.732487
# TorqueRPMTo                       308                 0.607447
# RonRating                       10967                21.629457
# SeatCapacity                       37                 0.072973
# ModelCode                       10430                20.570369
# BuildCountryOriginDescription       1                 0.001972
# ValvesCylinder                    510                 1.005838
# EngineCycleDescription              1                 0.001972
# EngineConfigurationDescription   1860                 3.668350
# EngineLocation                     13                 0.025639
# EngineNum                         804                 1.585674
# Acceleration                    35574                70.160145
# FrontTyreSize                     904                 1.782897
# RearTyreSize                      904                 1.782897
# FrontRimDesc                      726                 1.431840
# RearRimDesc                       726                 1.431840
# TowingBrakes                     2944                 5.806248
# TowingNoBrakes                   5200                10.255601
# WarrantyCustAssist              27949                55.121884
# FreeScheduledService            50608                99.810666
# WarrantyYears                    2614                 5.155412
# WarrantyKM                       2965                 5.847665
# FirstServiceKM                  19972                39.389397
# FirstServiceMonths              22813                44.992506
# RegServiceMonths                19958                39.361786
# AltEngEngineType                49866                98.347270
# AltEngBatteryType               49866                98.347270
# AltEngCurrentType               49866                98.347270
# AltEngAmpHours                  50698                99.988167
# AltEngVolts                     49868                98.351215
# AltEngChargingMethod            49866                98.347270
# AltEngPower                     49868                98.351215
# AltEngPowerFrom                 50548                99.692332
# AltEngPowerTo                   50467                99.532581
# AltEngTorque                    49919                98.451799
# AltEngTorqueFrom                50704               100.000000
# AltEngTorqueTo                  50540                99.676554
# AltEngDrive                     49869                98.353187
# NormalChargeMins                50704               100.000000
# QuickChargeMins                 50704               100.000000
# NormalChargeVoltage             50704               100.000000
# QuickChargeVoltage              50704               100.000000
# KMRangeElectricEng              50702                99.996056
# ElectricEngineLocation          50678                99.948722
# TopSpeedElectricEng             50702                99.996056
# GreenhouseRating                26060                51.396340
# AirpollutionRating              26074                51.423951
# OverallGreenStarRating          25883                51.047255
# CO2Combined                     16974                33.476649
# CO2Urban                        38592                76.112338
# CO2ExtraUrban                   38594                76.116283
# FuelUrban                       21310                42.028242
# FuelExtraurban                  22463                44.302225
# FuelCombined                     4358                 8.594983
# EmissionStandard                41755                82.350505
# MaxEthanolBlend                 48554                95.759703
# AncapRating                     24739                48.791022
# VFactsClass                       428                 0.844115
# VFactsSegment                     428                 0.844115
# VFactsPrice                     10381                20.473730
# IsPPlateApproved                    1                 0.001972
# AverageKM                           1                 0.001972
# GoodKM                              1                 0.001972
# AvgWholesale                    13110                25.855948
# AvgRetail                        4731                 9.330625
# GoodWholesale                    6753                13.318476
# GoodRetail                          1                 0.001972
# TradeMin                        13110                25.855948
# TradeMax                        13110                25.855948
# PrivateMax                          1                 0.001972
# NewPrice                            1                 0.001972
# Colour                             44                 0.086778
# Branch                              1                 0.001972
# SaleCategory                        1                 0.001972
# Sold_Date                           1                 0.001972
# Compliance_Date                    45                 0.088750
# Age_Comp_Months                    45                 0.088750
# KM                                  2                 0.003944
# Sold_Amount                         4                 0.007889

# %% [markdown]
# ## Data Preprosessing

# %%
# Mileage is one key factor in determining the price, thus excluded if missing. Only two rows, so impact is minimal
df = df.loc[~df['KM'].isnull()]

#Exclude rows without sold amount too as it is essential
df = df.loc[~df['Sold_Amount'].isnull()]

# %%
# Lets reduce the df size
df_filt = df[exploration_vars + [responding_var]]

# %%
df_filt = get_correct_dtype(df=df_filt, numeric_vars=ModelVariables().numeric_variables + [responding_var], categorical_vars=ModelVariables().categorical_variables, date_vars=ModelVariables().date_variables)
df_filt.dtypes
# Out:
# c:\Datium\data_utils.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.to_numeric(df[col], errors='coerce')
# c:\Datium\data_utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category')
# c:\Datium\data_utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category')
# c:\Datium\data_utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category')
# c:\Datium\data_utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category')
# c:\Datium\data_utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category')
# c:\Datium\data_utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category')
# c:\Datium\data_utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category')
# c:\Datium\data_utils.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# Power                                   float64
# NewPrice                                  int64
# GearNum                                   int64
# DoorNum                                   int64
# Cylinders                                 int64
# SeatCapacity                            float64
# WarrantyYears                           float64
# WarrantyKM                              float64
# Age_Comp_Months                         float64
# KM                                        int64
# MakeCode                               category
# FamilyCode                             category
# EngineDescription                      category
# FuelTypeDescription                    category
# RonRating                              category
# BuildCountryOriginDescription          category
# SaleCategory                           category
# Sold_Date                        datetime64[ns]
# Sold_Amount                             float64
# dtype: object

# %%
# Illustrate box plot for Sold_Amount

# Create a boxplot for Sold_Amount
fig = px.box(df_filt, y='Sold_Amount', title='Boxplot of Sold Amount')
fig.show()

# %%
# Assuming those missing data dont have warranty, thus replace None with 0
df_filt = get_available_free_warranty_year(df_filt)
df_filt = get_available_free_service_km(df_filt)

# Let's take the year of sold only
df_filt['Year_Sold'] = df_filt['Sold_Date'].dt.year
# Out:
# c:\Datium\data_utils.py:137: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Datium\data_utils.py:138: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Datium\data_utils.py:123: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Datium\data_utils.py:124: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\WAILO\AppData\Local\Temp\ipykernel_18188\1064672167.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Drop unwanted columns
df_processed = df_filt.drop(columns=ModelVariables().excluded_variables)

# %% [markdown]
# # Feel the dataset

# %%
# Let's have a look at R2 coefficient
from exploratory_utils import compute_r_squared
r_squared = compute_r_squared(data = df_processed[["Sold_Amount", "Power", "NewPrice", "GearNum", "DoorNum", "Cylinders", "SeatCapacity", "AvailableWarrantyYears", "AvailableWarrantyKM", "Age_Comp_Months", "KM"]], target_variable=responding_var)
r_squared
# Out:
#                  Variable  R-squared
# 0                   Power   0.055135
# 1                NewPrice   0.419871
# 2                 GearNum   0.030646
# 3                 DoorNum   0.005289
# 4               Cylinders   0.022976
# 5            SeatCapacity   0.030864
# 6  AvailableWarrantyYears   0.000662
# 7     AvailableWarrantyKM   0.085723
# 8         Age_Comp_Months   0.198694
# 9                      KM   0.131591

# %% [markdown]
# ## Visualization

# %%
# Initializa Plot Class
PlotClass = Plotting

# %%
PlotClass.create_correlation_grid(data=df_processed, target_var="Sold_Amount")

# From the graph, we can observe that
# There are abnormal outliers for AvailableWarrantyKM - we need to remove the outliers
# There is 1 outlier for KM - 8Million+ KM, we need to remove that
# There is 1 outlier for Age_Comp_Months, we need to remove that

fig.write_html("docs/subset.html") 
# refer to subset.html in docs folder
